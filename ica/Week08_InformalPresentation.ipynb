# %% [markdown]
# # CMSE 830 Midterm Project <br> Informal Group Presentations
#
# ---
#
# ## Overview
#
# Today is all about **learning from each other** in a supportive, informal setting. You'll share your midterm projects with your group, discuss your approaches, and teach each other "tricks" that will improve everyone's work. This is **not** a formal critique session - think of it as a collaborative workshop where you help each other succeed.
#
# **What you'll gain:**
# - See diverse approaches to the same assignment
# - Learn visualization techniques and Streamlit tricks
# - Get early feedback in a friendly environment
# - Discover storytelling strategies you hadn't considered
# - Build a toolkit of ideas to improve your project
#
# ---
#
# ### Activity Structure
#
# #### Suggested Timing Guidelines:
#
# **For groups of 4:**
# - 10 minutes per person to present + discuss
# - 15 minutes group synthesis and trick-sharing
# - **Total: ~55 minutes**
#
# **For groups of 5:**
# - 9 minutes per person to present + discuss
# - 15 minutes group synthesis and trick-sharing
# - **Total: ~60 minutes**
#
# **For groups of 6:**
# - 8 minutes per person to present + discuss
# - 15 minutes group synthesis and trick-sharing
# - **Total: ~63 minutes**
#
# **⏰ Appoint a timekeeper** to keep things moving fairly!

# %% [markdown]
# Belieu, Joshua Alan

# %% [markdown]
# ---
#
# ## Part 1: Individual Presentations (8-10 min each)
#
# Each person takes a turn presenting their project informally. This is **conversational**, not a formal presentation.
#
# ### What to Show (5 minutes):
# - Quick demo of your app - what does it do?
# - Walk through 2-3 key features or visualizations
# - Show something you're proud of
# - Show something you're struggling with
#
# ### What to Discuss (3-5 minutes):
# Using the questions below, have a **conversation** with your group. You don't need to answer all questions - pick the ones most relevant to your project or that will help you most.
#
# ### Discussion Questions
#
# *Use these to guide your conversations - not a checklist to complete!*
#
# #### 🎯 Project Narrative & Goals
#
# **For the presenter to discuss:**
#
# 1. **What is the main question or problem your project addresses?** Can you state it in one sentence?
# 2. **What story are you trying to tell with your data?** Walk us through the narrative arc of your app.
# 3. **Who is your intended audience?** (General public? Domain experts? Decision-makers?)
# 4. **What insight do you want users to leave with?**
#
# **For the group to explore:**
#
# 5. **Is the story clear from the presenter's demo?** What questions do you still have?
# 6. **How would you explain this project to someone else?** (If you can't, the narrative needs work!)
#
# #### 📊 Data Collection & Preparation
#
# **For the presenter to share:**
#
# 7. **What are your two (or more) data sources?** Where did you find them?
# 8. **What challenges did you face integrating multiple datasets?** How did you overcome them?
# 9. **What data cleaning steps were most critical?** Why?
# 10. **Did you discover any surprising data quality issues?** How did you handle them?
#
# **Group discussion:**
#
# 11. **What data wrangling trick or resource would you recommend to others?**
# 12. **Has anyone else dealt with similar data challenges?** Share solutions!
#
# #### 📈 Visualization Strategy
#
# **For the presenter to explain:**
#
# 13. **What are your 3+ visualization types?** Why did you choose each one?
# 14. **Which visualization is most effective at communicating your message?** Why?
# 15. **What visualization choices did you struggle with?** (Color schemes? Chart types? Layout?)
# 16. **How did you ensure your encodings are appropriate?** (e.g., categorical vs. continuous data)
#
# **Group brainstorm:**
#
# 17. **What visualization technique, library, or design principle did you discover that others should try?**
# 18. **Does the group have suggestions for alternative visualizations?**
# 19. **What visualization from this presentation would you want to learn how to make?**
#
# #### 🔧 Data Processing & Missing Data
#
# **For the presenter:**
#
# 20. **How much missing data did you encounter?** In which variables?
# 21. **What imputation technique(s) did you use?** Why did you choose that approach?
# 22. **How did you validate that your imputation was reasonable?**
# 23. **Did you handle missingness differently for different variables?** Explain your reasoning.
#
# **Group sharing:**
#
# 24. **Has anyone used a different imputation approach?** What worked or didn't work?
#
# #### 💻 Streamlit App Features
#
# **For the presenter to demonstrate:**
#
# 25. **Walk us through your app structure.** How many pages/sections do you have?
# 26. **What are your 2+ interactive elements?** (Sliders? Dropdowns? Buttons?)
# 27. **What Streamlit feature was hardest to implement?** How did you figure it out?
# 28. **How does your app guide users through your narrative?**
# 29. **Is your app self-documenting?** How do new users know what to do?
#
# **THIS IS KEY FOR TODAY:**
#
# 30. **Share with the group: What's the coolest Streamlit trick or feature you implemented?**
#     - Show the code if possible!
#     - Explain where you found the solution
#     - Demonstrate how it works
#
# **Group learning:**
#
# 31. **Has anyone implemented similar features differently?** Compare approaches!
# 32. **What Streamlit challenges is the group collectively facing?** Brainstorm solutions together.
#
# #### 📁 GitHub & Documentation
#
# **Quick check:**
#
# 33. **Is your README clear about what the project does and how to run it?**
# 34. **How are you organizing your repository?** (File structure, naming conventions)
# 35. **What GitHub or documentation practice is working well for you?**
#
# #### 🚀 Above & Beyond Opportunities
#
# **Group brainstorm:**
#
# 36. **What "Above and Beyond" elements are you planning to include?**
# 37. **Where could you push your project further before the deadline?**
# 38. **What's one ambitious feature you're considering but aren't sure how to implement?**
#     - *Group: Help brainstorm approaches or share resources!*
#
# #### 💭 Constructive Support
#
# **After each person shares, the group should discuss:**
#
# 39. **What's working really well in this project?** (Be specific with praise!)
# 40. **What's one gentle suggestion for improvement?**
# 41. **What questions do you have about the app or approach?**
# 42. **What element from this project might you adapt for your own?**

# %% [markdown]
# ✏️ **Answer** Use this space to take notes
#
#
# Me :
#
# They liked the datasets tab and general format of the app.
#
# Dennis :
#
# I liked Dennis' statistics representation at each step of the plot ivestigation. I suggested adding an animation for some of his statistics. I think I will try to use a slider he had to reduce the sample size for his plots.
#
# Josh N. :
#
# I liked the thorough-ness of his plots. I gave some suggestions regarding how his plots were styled.
#
# Batu :
#
# Batu gave good explanation of his features and had good bones for his app. It seemed like his Anaconda distribution was misbehaving so I suggested maybe dropping it as it is notorious for being problematic.
#
# Ethan :
#
# Ethan chose to do an analysis over pitchers and catchers which sounded cool to me and ambitious as he would have to do double the analysis for his project.
#
# Ethan :
#
# Ethan walked us through the concepts of his project but was unable to show any plots at the time.

# %% [markdown]
# ---
#
# ## Part 2: Group Synthesis & Trick Sharing (Final 15 minutes)
#
# After everyone has presented, come together as a group for collaborative learning.
#
# ### 🎓 Share Your "Tricks"
#
# Go around the group and each person shares:
#
# **1. Streamlit Trick (2 min per person)**
# - Demonstrate or explain one Streamlit technique you figured out
# - Share the code snippet if possible
# - Explain where you learned it (documentation, Stack Overflow, experimentation?)
# - Common examples:
#   - Layout tricks (columns, expanders, tabs)
#   - File uploaders or downloads
#   - Interactive widgets
#
# **2. Visualization Technique (1-2 min per person)**
# - Show or describe one visualization you're proud of
# - Explain the design decisions behind it
# - Share any libraries or resources that helped (Plotly, Seaborn, Altair, etc.)
# - What makes it effective?
#
# **3. Storytelling Approach (1-2 min per person)**
# - How are you structuring your narrative?
# - How are you guiding users through the app?
# - What's your strategy for making the message clear?
# - Even if it's not perfect yet, what's your plan?
#
# ### 📝 Group Discussion:
#
# Take a few minutes to collectively discuss:
#
# 43. What patterns did you notice across all projects?
# 44. What's the most creative solution someone shared?
# 45. What common challenge is everyone facing?
# 46. What resources should the group collectively explore? (Documentation, tutorials, Stack Overflow threads, etc.)
# 47. What question should someone ask in office hours on behalf of the group?

# %% [markdown]
# ✏️ **Answer** Use this space to take notes
#
# I was so engrossed in the discussion I neglected to keep good notes :3

# %% [markdown]
# ### Instructions for submitting
#
# **Each student submits one notebook by the end of today**. In the next markdown cell write 2-3 paragraphs addressing:
#
# #### Section 1: What You Learned From Your Group
# Answer these questions:
# - What's one visualization idea you learned from your group that you want to incorporate? Be specific about what it is and which project inspired it.
# - What's one Streamlit trick you learned that you'll implement? Explain what it does and how it will improve your project.
# - What's one approach to storytelling/narrative you'll adopt? How will this make your project clearer?
#
# #### Section 2: What You'll Change
# Answer these questions:
# - What's one thing you're going to change about your project based on today's discussion? Be specific about the change and why.
# - What feedback or suggestion was most valuable? Who suggested it and how will you implement it?
#
# #### Section 3: Your Contribution
# Answer this question:
# - What trick or technique did you share with your group? Briefly describe what you taught others.

# %% [markdown]
# ✏️ **Answer** Write your reflections here
#
# Dennis had a cool slider that updated his plot and removed data according to the range of the slider. We all had similar implementations so I did not take anything away necessarily. I do think I walked away with some style ideas however! After practicing talking about my data sets I realized I left their original names. The names are important for proper attributation of the work but I think I will refer to them as a common name and give thanks explicitly somewhere else. This will peel back a layer of abstraction in the storytelling. I showed the group the navigation page setup I use on the side of the app. It looks nice and is convenient for sorting all the pages.

# %% [markdown]
# ---
# ### After Today: Preparing for Thursday
#
# Remember, Thursday is a **different format**:
# - You'll present to a **new, random group**
# - It will be more **formal and structured**
# - You'll give and receive **written feedback forms**
# - The goal is **fresh perspective and critical review**
#
# **Between Tuesday and Thursday:**
# - Implement the tricks you learned today
# - Address feedback from your group
# - Polish your app based on suggestions
# - Prepare for more structured presentation on Thursday

# %% [markdown]
# ---
#
# ## Congratulations, you’re done!
#
# Submit this assignment by uploading it to the course Desire2Learn web page. Go to the “In-class assignments” folder, find the appropriate submission link, and upload it there.

# %% [markdown]
# &#169; Copyright 2025, Department of Computational Mathematics, Science and Engineering at Michigan State University.
